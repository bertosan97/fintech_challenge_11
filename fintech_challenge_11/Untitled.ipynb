# %%
conda install -c anaconda ephem
# Out:
# Retrieving notices: ...working... done
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge pystan
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/gilbertosanchez/opt/anaconda3/envs/dev
#
#   added / updated specs:
#     - pystan
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2022.12.7  |       h033912b_0         142 KB  conda-forge
#     cctools_osx-64-973.0.1     |       h3e07e27_2         2.0 MB  conda-forge
#     certifi-2022.12.7          |     pyhd8ed1ab_0         147 KB  conda-forge
#     clang-11.1.0               |       h694c41f_1         125 KB  conda-forge
#     clang-11-11.1.0            |default_he082bbe_1         684 KB  conda-forge
#     clang_osx-64-11.1.0        |       hc8532ff_7          16 KB  conda-forge
#     clangxx-11.1.0             |default_he082bbe_1         125 KB  conda-forge
#     clangxx_osx-64-11.1.0      |       h2c55bc3_7          16 KB  conda-forge
#     clikit-0.6.2               |     pyh9f0ad1d_0          56 KB  conda-forge
#     compiler-rt-11.1.0         |       h654b07c_0          78 KB  conda-forge
#     compiler-rt_osx-64-11.1.0  |       h8c5fa43_0         5.6 MB  conda-forge
#     crashtest-0.3.1            |     pyhd8ed1ab_0           9 KB  conda-forge
#     httpstan-4.5.0             |   py37h737db71_0          88 KB  conda-forge
#     ld64_osx-64-609            |      h6adca69_10         1.5 MB  conda-forge
#     ldid-2.1.2                 |       h6a69015_3          55 KB  conda-forge
#     libclang-cpp11.1-11.1.0    |default_he082bbe_1        12.6 MB  conda-forge
#     libllvm12-12.0.1           |       hd011deb_2        24.1 MB  conda-forge
#     llvm-tools-11.1.0          |       h46f1229_1         9.2 MB
#     lz4-4.0.0                  |   py37hf9031b7_2          33 KB  conda-forge
#     marshmallow-3.19.0         |     pyhd8ed1ab_0          83 KB  conda-forge
#     openssl-1.1.1s             |       hfd90126_1         1.6 MB  conda-forge
#     pastel-0.2.1               |     pyhd8ed1ab_0          10 KB  conda-forge
#     pylev-1.4.0                |     pyhd8ed1ab_0           9 KB  conda-forge
#     pysimdjson-4.0.2           |   py37hd8d24ac_2         162 KB  conda-forge
#     pystan-3.3.0               |   py37h326c9ff_0          27 KB  conda-forge
#     python_abi-3.7             |          2_cp37m           4 KB  conda-forge
#     sigtool-0.1.3              |       h57ddcff_0         209 KB  conda-forge
#     tapi-1100.0.11             |       h9ce4665_0         196 KB  conda-forge
#     webargs-8.2.0              |     pyhd8ed1ab_0          26 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        58.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   cctools_osx-64     conda-forge/osx-64::cctools_osx-64-973.0.1-h3e07e27_2
#   clang              conda-forge/osx-64::clang-11.1.0-h694c41f_1
#   clang-11           conda-forge/osx-64::clang-11-11.1.0-default_he082bbe_1
#   clang_osx-64       conda-forge/osx-64::clang_osx-64-11.1.0-hc8532ff_7
#   clangxx            conda-forge/osx-64::clangxx-11.1.0-default_he082bbe_1
#   clangxx_osx-64     conda-forge/osx-64::clangxx_osx-64-11.1.0-h2c55bc3_7
#   clikit             conda-forge/noarch::clikit-0.6.2-pyh9f0ad1d_0
#   compiler-rt        conda-forge/osx-64::compiler-rt-11.1.0-h654b07c_0
#   compiler-rt_osx-64 conda-forge/noarch::compiler-rt_osx-64-11.1.0-h8c5fa43_0
#   crashtest          conda-forge/noarch::crashtest-0.3.1-pyhd8ed1ab_0
#   httpstan           conda-forge/osx-64::httpstan-4.5.0-py37h737db71_0
#   ld64_osx-64        conda-forge/osx-64::ld64_osx-64-609-h6adca69_10
#   ldid               conda-forge/osx-64::ldid-2.1.2-h6a69015_3
#   libclang-cpp11.1   conda-forge/osx-64::libclang-cpp11.1-11.1.0-default_he082bbe_1
#   libllvm12          conda-forge/osx-64::libllvm12-12.0.1-hd011deb_2
#   llvm-tools         pkgs/main/osx-64::llvm-tools-11.1.0-h46f1229_1
#   lz4                conda-forge/osx-64::lz4-4.0.0-py37hf9031b7_2
#   marshmallow        conda-forge/noarch::marshmallow-3.19.0-pyhd8ed1ab_0
#   pastel             conda-forge/noarch::pastel-0.2.1-pyhd8ed1ab_0
#   pylev              conda-forge/noarch::pylev-1.4.0-pyhd8ed1ab_0
#   pysimdjson         conda-forge/osx-64::pysimdjson-4.0.2-py37hd8d24ac_2
#   pystan             conda-forge/osx-64::pystan-3.3.0-py37h326c9ff_0
#   python_abi         conda-forge/osx-64::python_abi-3.7-2_cp37m
#   sigtool            conda-forge/osx-64::sigtool-0.1.3-h57ddcff_0
#   tapi               conda-forge/osx-64::tapi-1100.0.11-h9ce4665_0
#   webargs            conda-forge/noarch::webargs-8.2.0-pyhd8ed1ab_0
#
# The following packages will be UPDATED:
#
#   ca-certificates    anaconda::ca-certificates-2022.4.26-h~ --> conda-forge::ca-certificates-2022.12.7-h033912b_0
#   certifi            anaconda/osx-64::certifi-2022.6.15-py~ --> conda-forge/noarch::certifi-2022.12.7-pyhd8ed1ab_0
#   openssl               anaconda::openssl-1.1.1o-hca72f7f_0 --> conda-forge::openssl-1.1.1s-hfd90126_1
#
#
#
# Downloading and Extracting Packages
# marshmallow-3.19.0   | 83 KB     |                                       |   0%
# crashtest-0.3.1      | 9 KB      |                                       |   0%
#
# clang-11-11.1.0      | 684 KB    |                                       |   0%
#
#
# libclang-cpp11.1-11. | 12.6 MB   |                                       |   0%
#
#
#
# clangxx_osx-64-11.1. | 16 KB     |                                       |   0%
#
#
#
#
# clang_osx-64-11.1.0  | 16 KB     |                                       |   0%
#
#
#
#
#
# clang-11.1.0         | 125 KB    |                                       |   0%
#
#
#
#
#
#
# ld64_osx-64-609      | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
# pysimdjson-4.0.2     | 162 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# httpstan-4.5.0       | 88 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
# pylev-1.4.0          | 9 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# python_abi-3.7       | 4 KB      |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1s       | 1.6 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# clikit-0.6.2         | 56 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ldid-2.1.2           | 55 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# clangxx-11.1.0       | 125 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# compiler-rt-11.1.0   | 78 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sigtool-0.1.3        | 209 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cctools_osx-64-973.0 | 2.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm12-12.0.1     | 24.1 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 147 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2022 | 142 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pastel-0.2.1         | 10 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# crashtest-0.3.1      | 9 KB      | ##################################### | 100%
#
# marshmallow-3.19.0   | 83 KB     | #######1                              |  19%
#
#
#
# clangxx_osx-64-11.1. | 16 KB     | ##################################### | 100%
#
#
# libclang-cpp11.1-11. | 12.6 MB   |                                       |   0%
# crashtest-0.3.1      | 9 KB      | ##################################### | 100%
#
#
#
# marshmallow-3.19.0   | 83 KB     | ##################################### | 100%
#
#
#
#
#
#
# ld64_osx-64-609      | 1.5 MB    | 3                                     |   1%
#
#
#
#
# clang_osx-64-11.1.0  | 16 KB     | ####################################5 |  99%
#
#
#
#
# clang_osx-64-11.1.0  | 16 KB     | ##################################### | 100%
#
# clang-11-11.1.0      | 684 KB    | ##################################### | 100%
#
#
# libclang-cpp11.1-11. | 12.6 MB   | ##8                                   |   8%
#
#
#
#
#
#
# ld64_osx-64-609      | 1.5 MB    | ##7                                   |   8%
#
#
#
#
#
# clang-11.1.0         | 125 KB    | ####7                                 |  13%
#
# clang-11-11.1.0      | 684 KB    | ##################################### | 100%
#
#
#
#
#
# clang-11.1.0         | 125 KB    | ##################################### | 100%
#
#
# libclang-cpp11.1-11. | 12.6 MB   | ####4                                 |  12%
#
#
#
#
#
#
#
# pysimdjson-4.0.2     | 162 KB    | ###6                                  |  10%
#
#
#
#
#
#
# ld64_osx-64-609      | 1.5 MB    | ###########################8          |  75%
#
#
#
#
#
#
#
#
#
# pylev-1.4.0          | 9 KB      | ##################################### | 100%
#
#
#
#
#
#
#
# pysimdjson-4.0.2     | 162 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# pylev-1.4.0          | 9 KB      | ##################################### | 100%
#
#
# libclang-cpp11.1-11. | 12.6 MB   | #################4                    |  47%
#
#
#
#
#
#
#
#
# httpstan-4.5.0       | 88 KB     | ######7                               |  18%
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1s       | 1.6 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
# python_abi-3.7       | 4 KB      | ##################################### | 100%
#
#
#
#
#
#
# ld64_osx-64-609      | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# python_abi-3.7       | 4 KB      | ##################################### | 100%
#
#
#
#
#
#
#
#
# httpstan-4.5.0       | 88 KB     | ##################################### | 100%
#
#
# libclang-cpp11.1-11. | 12.6 MB   | #######################3              |  63%
#
#
#
#
#
#
#
#
#
#
#
#
# clikit-0.6.2         | 56 KB     | ##########5                           |  29%
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1s       | 1.6 MB    | ###################2                  |  52%
#
#
#
#
#
#
#
#
#
#
#
#
# clikit-0.6.2         | 56 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ldid-2.1.2           | 55 KB     | ##########6                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# clangxx-11.1.0       | 125 KB    | ####7                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
#
#
# ldid-2.1.2           | 55 KB     | ##################################### | 100%
#
#
# libclang-cpp11.1-11. | 12.6 MB   | ############################3         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# compiler-rt-11.1.0   | 78 KB     | #######5                              |  20%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sigtool-0.1.3        | 209 KB    | ##8                                   |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm12-12.0.1     | 24.1 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cctools_osx-64-973.0 | 2.0 MB    | 2                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2022 | 142 KB    | ####1                                 |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 147 KB    | ####                                  |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm12-12.0.1     | 24.1 MB   | #####6                                |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pastel-0.2.1         | 10 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm12-12.0.1     | 24.1 MB   | ###############1                      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm12-12.0.1     | 24.1 MB   | ########################1             |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm12-12.0.1     | 24.1 MB   | ###############################5      |  85%
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1s       | 1.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# openssl-1.1.1s       | 1.6 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# clangxx-11.1.0       | 125 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# clangxx-11.1.0       | 125 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# compiler-rt-11.1.0   | 78 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# compiler-rt-11.1.0   | 78 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sigtool-0.1.3        | 209 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# sigtool-0.1.3        | 209 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cctools_osx-64-973.0 | 2.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cctools_osx-64-973.0 | 2.0 MB    | ##################################### | 100%
#
#
# libclang-cpp11.1-11. | 12.6 MB   | ##################################### | 100%
#
#
# libclang-cpp11.1-11. | 12.6 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2022 | 142 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2022 | 142 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 147 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2022.12.7    | 147 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pastel-0.2.1         | 10 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libllvm12-12.0.1     | 24.1 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge fbprophet
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/gilbertosanchez/opt/anaconda3/envs/dev
#
#   added / updated specs:
#     - fbprophet
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     convertdate-2.4.0          |     pyhd8ed1ab_0          38 KB  conda-forge
#     fbprophet-0.4.post2        |   py37h0a44026_0         611 KB  conda-forge
#     hijri-converter-2.2.4      |     pyhd8ed1ab_0          18 KB  conda-forge
#     holidays-0.18              |     pyhd8ed1ab_0         105 KB  conda-forge
#     korean_lunar_calendar-0.3.1|     pyhd8ed1ab_0          12 KB  conda-forge
#     lunardate-0.2.0            |             py_0          21 KB  conda-forge
#     pymeeus-0.5.12             |     pyhd8ed1ab_0         507 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   convertdate        conda-forge/noarch::convertdate-2.4.0-pyhd8ed1ab_0
#   fbprophet          conda-forge/osx-64::fbprophet-0.4.post2-py37h0a44026_0
#   hijri-converter    conda-forge/noarch::hijri-converter-2.2.4-pyhd8ed1ab_0
#   holidays           conda-forge/noarch::holidays-0.18-pyhd8ed1ab_0
#   korean_lunar_cale~ conda-forge/noarch::korean_lunar_calendar-0.3.1-pyhd8ed1ab_0
#   lunardate          conda-forge/noarch::lunardate-0.2.0-py_0
#   pymeeus            conda-forge/noarch::pymeeus-0.5.12-pyhd8ed1ab_0
#
#
#
# Downloading and Extracting Packages
# pymeeus-0.5.12       | 507 KB    |                                       |   0%
# holidays-0.18        | 105 KB    |                                       |   0%
#
# fbprophet-0.4.post2  | 611 KB    |                                       |   0%
#
#
# convertdate-2.4.0    | 38 KB     |                                       |   0%
#
#
#
# lunardate-0.2.0      | 21 KB     |                                       |   0%
#
#
#
#
# hijri-converter-2.2. | 18 KB     |                                       |   0%
#
#
#
#
#
# korean_lunar_calenda | 12 KB     |                                       |   0%
#
#
# pymeeus-0.5.12       | 507 KB    | #1                                    |   3%
#
#
# convertdate-2.4.0    | 38 KB     | ##################################### | 100%
#
#
#
# lunardate-0.2.0      | 21 KB     | ############################2         |  76%
#
#
#
# lunardate-0.2.0      | 21 KB     | ##################################### | 100%
# holidays-0.18        | 105 KB    | #####6                                |  15%
#
#
#
#
# hijri-converter-2.2. | 18 KB     | #################################7    |  91%
#
#
#
#
#
# korean_lunar_calenda | 12 KB     | ##################################### | 100%
#
#
#
#
# hijri-converter-2.2. | 18 KB     | ##################################### | 100%
#
# fbprophet-0.4.post2  | 611 KB    | 9                                     |   3%
#
# fbprophet-0.4.post2  | 611 KB    | ##########################1           |  71%
# holidays-0.18        | 105 KB    | ##################################### | 100%
# holidays-0.18        | 105 KB    | ##################################### | 100%
#
#
#
#
#
# pymeeus-0.5.12       | 507 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.
